# %%
# define indicies
import numpy as np

np.random.seed(9)

house_ids = range(1,1461)
random_id = np.random.choice(house_ids, 1460, replace = False)
len(random_id)
# Out:
# 1460

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/train_model.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  Id  LotFrontage  LotArea  YearBuilt  GrLivArea  YrSold  \
# 0           0   1         65.0     8450          7       1710    2008
# 1           1   2         80.0     9600         34       1262    2007
# 2           2   3         68.0    11250          9       1786    2008
# 3           3   4         60.0     9550         95       1717    2006
# 4           4   5         84.0    14260         10       2198    2008
#
#    SalePrice  MSZoning_RL  MSZoning_RMH                 ...                   \
# 0     208500            1             0                 ...
# 1     181500            1             0                 ...
# 2     223500            1             0                 ...
# 3     140000            1             0                 ...
# 4     250000            1             0                 ...
#
#    OpenPorchSF_OpenPorch_Yes  Fence_no_fence  MoSold_peak_months  \
# 0                          1               1                   0
# 1                          0               1                   1
# 2                          1               1                   0
# 3                          1               1                   0
# 4                          1               1                   0
#
#    SaleType_non_deed  SaleCondition_not_normal  IsVinyl_yes  \
# 0                  0                         0            1
# 1                  0                         0            0
# 2                  0                         0            1
# 3                  0                         1            0
# 4                  0                         0            1
#
#    FullBaths_<=1FullBath  FullBaths_>=3FullBaths  HalfBaths_>=1HalfBaths  \
# 0                      0                       1                       1
# 1                      0                       0                       1
# 2                      0                       1                       1
# 3                      0                       0                       0
# 4                      0                       1                       1
#
#    Enclosed_combined_EnclosedPorch_Yes
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    1
# 4                                    0
#
# [5 rows x 72 columns]

# %%
df.drop(columns = ['Unnamed: 0', 'Id'], inplace = True)

# %%
df['random_id'] = random_id

# %%
df.set_index('random_id', inplace = True)

# %%
df.sort_index(inplace=True)

# %%
df.head(5)
# Out:
#            LotFrontage  LotArea  YearBuilt  GrLivArea  YrSold  SalePrice  \
# random_id
# 1                 87.0     9246         37       1656    2008     135000
# 2                 60.0     7200         60       1904    2009     138000
# 3                 74.0     8532         56       1297    2009     153000
# 4                 47.0    53504          7       3279    2010     538000
# 5                 82.0     9430         11       2365    2009     337000
#
#            MSZoning_RL  MSZoning_RMH  Alley_NoAccess  LotShape_Regular  \
# random_id
# 1                    1             0               1                 0
# 2                    1             0               1                 1
# 3                    1             0               1                 1
# 4                    1             0               1                 0
# 5                    1             0               1                 1
#
#                           ...                   OpenPorchSF_OpenPorch_Yes  \
# random_id                 ...
# 1                         ...                                           1
# 2                         ...                                           0
# 3                         ...                                           0
# 4                         ...                                           1
# 5                         ...                                           1
#
#            Fence_no_fence  MoSold_peak_months  SaleType_non_deed  \
# random_id
# 1                       1                   0                  0
# 2                       0                   1                  0
# 3                       1                   0                  0
# 4                       1                   1                  0
# 5                       1                   1                  0
#
#            SaleCondition_not_normal  IsVinyl_yes  FullBaths_<=1FullBath  \
# random_id
# 1                                 0            0                      0
# 2                                 0            1                      0
# 3                                 0            0                      1
# 4                                 0            0                      0
# 5                                 0            1                      0
#
#            FullBaths_>=3FullBaths  HalfBaths_>=1HalfBaths  \
# random_id
# 1                               0                       0
# 2                               0                       1
# 3                               0                       1
# 4                               1                       1
# 5                               1                       1
#
#            Enclosed_combined_EnclosedPorch_Yes
# random_id
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            1
# 5                                            1
#
# [5 rows x 70 columns]

# %%
test_1 = df.iloc[0:292,:]
test_2 = df.iloc[292:584,:]
test_3 = df.iloc[584:876,:]
test_4 = df.iloc[876:1168,:]
test_5 = df.iloc[1168:1460,:]

# %%
print(len(test_1))
print(len(test_2))
print(len(test_3))
print(len(test_4))
print(len(test_5))
# Out:
# 292
# 292
# 292
# 292
# 292

# %%
group_test = test_1.copy()
group_train = pd.concat([test_2, test_3, test_4, test_5])
group_train.shape
group_train.head(5)
# Out:
#            LotFrontage  LotArea  YearBuilt  GrLivArea  YrSold  SalePrice  \
# random_id
# 293          70.049958    13837         22       2183    2006     229000
# 294          51.000000     8029          5       1456    2008     176000
# 295          86.000000    13286          3       1698    2009     320000
# 296          60.000000     9600         86       1096    2008      79000
# 297          90.000000    10800         36       2614    2008     240000
#
#            MSZoning_RL  MSZoning_RMH  Alley_NoAccess  LotShape_Regular  \
# random_id
# 293                  1             0               1                 0
# 294                  1             0               1                 0
# 295                  1             0               1                 0
# 296                  1             0               1                 1
# 297                  1             0               1                 1
#
#                           ...                   OpenPorchSF_OpenPorch_Yes  \
# random_id                 ...
# 293                       ...                                           0
# 294                       ...                                           1
# 295                       ...                                           1
# 296                       ...                                           1
# 297                       ...                                           1
#
#            Fence_no_fence  MoSold_peak_months  SaleType_non_deed  \
# random_id
# 293                     1                   0                  0
# 294                     1                   1                  0
# 295                     1                   0                  0
# 296                     1                   0                  0
# 297                     1                   1                  0
#
#            SaleCondition_not_normal  IsVinyl_yes  FullBaths_<=1FullBath  \
# random_id
# 293                               0            0                      0
# 294                               0            1                      0
# 295                               0            0                      0
# 296                               0            0                      1
# 297                               0            0                      0
#
#            FullBaths_>=3FullBaths  HalfBaths_>=1HalfBaths  \
# random_id
# 293                             0                       1
# 294                             0                       1
# 295                             1                       0
# 296                             0                       0
# 297                             0                       1
#
#            Enclosed_combined_EnclosedPorch_Yes
# random_id
# 293                                          0
# 294                                          0
# 295                                          0
# 296                                          1
# 297                                          0
#
# [5 rows x 70 columns]

# %% [markdown]
# # Model

# %%
from sklearn import linear_model
ols = linear_model.LinearRegression()

# %%
X_train = group_train.drop(['SalePrice'], axis = 1)
y_train = np.log(group_train.SalePrice)

X_test = group_test.drop('SalePrice', axis = 1)
y_test = np.log(group_test.SalePrice)

# %% [markdown]
# https://medium.com/@emredjan/emulating-r-regression-plots-in-python-43741952c034

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm

from statsmodels.graphics.gofplots import ProbPlot

plt.style.use('seaborn') # pretty matplotlib plots

plt.rc('font', size=14)
plt.rc('figure', titlesize=18)
plt.rc('axes', labelsize=15)
plt.rc('axes', titlesize=18)
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
X_train = sm.add_constant(X_train) 
model2 = sm.OLS(y_train, X_train)
model_fit2 = model2.fit()
#print(model_fit2.summary())

# %%
X_train = sm.add_constant(X_train) 
model = smf.OLS(y_train, X_train)
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     122.9
# Date:                Wed, 30 May 2018   Prob (F-statistic):               0.00
# Time:                        17:44:25   Log-Likelihood:                 690.05
# No. Observations:                1168   AIC:                            -1242.
# Df Residuals:                    1099   BIC:                            -892.8
# Df Model:                          68
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  13.0718      5.044      2.592      0.010       3.175      22.968
# LotFrontage                            -0.0008      0.000     -3.094      0.002      -0.001      -0.000
# LotArea                              2.647e-06   8.27e-07      3.202      0.001    1.02e-06    4.27e-06
# YearBuilt                            6.245e-05      0.000      0.179      0.858      -0.001       0.001
# GrLivArea                               0.0002   1.75e-05     10.965      0.000       0.000       0.000
# YrSold                                 -0.0023      0.003     -0.725      0.469      -0.008       0.004
# MSZoning_RL                          7.094e-05      0.023      0.003      0.998      -0.046       0.046
# MSZoning_RMH                           -0.0388      0.025     -1.528      0.127      -0.089       0.011
# Alley_NoAccess                         -0.0189      0.020     -0.937      0.349      -0.058       0.021
# LotShape_Regular                        0.0011      0.010      0.107      0.915      -0.019       0.021
# LandContour_Unflat                     -0.0289      0.018     -1.596      0.111      -0.064       0.007
# LotConfig_CulDSac                       0.0428      0.020      2.088      0.037       0.003       0.083
# LotConfig_Inside                       -0.0089      0.011     -0.828      0.408      -0.030       0.012
# LandSlope_NGtl                          0.0322      0.023      1.396      0.163      -0.013       0.077
# Neighborhood_NAmes                      0.0875      0.016      5.324      0.000       0.055       0.120
# Neighborhood_SAmes                      0.0517      0.013      3.891      0.000       0.026       0.078
# Condition1_NormP                        0.0759      0.014      5.522      0.000       0.049       0.103
# BldgType_OneFamily                     -0.0322      0.032     -1.017      0.309      -0.094       0.030
# BldgType_Townhouse                     -0.1290      0.036     -3.619      0.000      -0.199      -0.059
# HouseStyle_OneStoryUp                  -0.0066      0.013     -0.495      0.621      -0.033       0.020
# OverallQual_HighQ                       0.1105      0.017      6.582      0.000       0.078       0.143
# OverallQual_LowQ                       -0.0860      0.017     -5.207      0.000      -0.118      -0.054
# OverallCond_BadC                       -0.1464      0.020     -7.230      0.000      -0.186      -0.107
# OverallCond_GoodC                       0.0725      0.020      3.691      0.000       0.034       0.111
# RoofStyle_not_gable                     0.0147      0.011      1.362      0.173      -0.006       0.036
# MasVnrType_no_masvnr                   -0.0078      0.010     -0.763      0.446      -0.028       0.012
# ExterQual_low                          -0.0300      0.015     -2.010      0.045      -0.059      -0.001
# ExterCond_low                          -0.0045      0.015     -0.291      0.771      -0.034       0.026
# Foundation_pconc                        0.0269      0.014      1.945      0.052      -0.000       0.054
# BsmtQual_low                           -0.0316      0.015     -2.077      0.038      -0.061      -0.002
# BsmtCond_low                           -0.0187      0.022     -0.865      0.387      -0.061       0.024
# BsmtExposure_no_exposure               -0.0203      0.011     -1.911      0.056      -0.041       0.001
# BsmtFinType1_undeveloped               -0.0374      0.010     -3.634      0.000      -0.058      -0.017
# TotalBsmtSF_mhigh                      -0.0581      0.014     -4.075      0.000      -0.086      -0.030
# TotalBsmtSF_mlow                       -0.0977      0.017     -5.833      0.000      -0.131      -0.065
# TotalBsmtSF_small                      -0.1565      0.019     -8.441      0.000      -0.193      -0.120
# HeatingQC_low                          -0.0153      0.011     -1.388      0.165      -0.037       0.006
# CentralAir_NoCentAir                   -0.1207      0.021     -5.685      0.000      -0.162      -0.079
# Electrical_StdCBrkr                    -0.0017      0.017     -0.104      0.917      -0.034       0.031
# BedroomAbvGr_=3Bedr                    -0.0079      0.012     -0.643      0.520      -0.032       0.016
# BedroomAbvGr_>=4Bedr                    0.0150      0.019      0.796      0.426      -0.022       0.052
# KitchenAbvGr_>=2Ktchn                  -0.1153      0.035     -3.260      0.001      -0.185      -0.046
# KitchenQual_ExKtchnQ                    0.1185      0.023      5.164      0.000       0.073       0.164
# KitchenQual_GdKtchnQ                    0.0368      0.013      2.905      0.004       0.012       0.062
# TotRmsAbvGrd_<=4TotRms                 -0.0318      0.018     -1.815      0.070      -0.066       0.003
# TotRmsAbvGrd_>=8TotRms                  0.0146      0.015      0.967      0.334      -0.015       0.044
# Functional_TypFunc                      0.0655      0.017      3.776      0.000       0.031       0.100
# Fireplaces_NoFireplace                 -0.0233      0.012     -1.872      0.062      -0.048       0.001
# FireplaceQu_OthFireplace               -0.0400      0.013     -3.111      0.002      -0.065      -0.015
# GarageType_Detached                    -0.0028      0.014     -0.205      0.837      -0.029       0.024
# GarageFinish_GarageUnf                 -0.0187      0.015     -1.257      0.209      -0.048       0.010
# GarageFinish_NoGarageFin                3.1952      1.262      2.532      0.011       0.719       5.671
# GarageFinish_RoughGarageFin            -0.0044      0.012     -0.369      0.712      -0.028       0.019
# GarageCars_1                            3.2321      1.261      2.563      0.011       0.758       5.707
# GarageCars_2                            3.2826      1.261      2.603      0.009       0.809       5.757
# GarageCars_AtLeast3                     3.3618      1.260      2.667      0.008       0.889       5.835
# GarageQual_GarageQual_not_good         -0.0211      0.029     -0.736      0.462      -0.077       0.035
# GarageCond_GarageCond_not_good         -0.0561      0.032     -1.771      0.077      -0.118       0.006
# PavedDrive_Y                            0.0430      0.018      2.409      0.016       0.008       0.078
# WoodDeckSF_WoodDeck_Yes                 0.0030      0.009      0.316      0.752      -0.016       0.022
# OpenPorchSF_OpenPorch_Yes               0.0015      0.010      0.151      0.880      -0.018       0.021
# Fence_no_fence                          0.0041      0.011      0.359      0.720      -0.018       0.026
# MoSold_peak_months                      0.0181      0.008      2.155      0.031       0.002       0.035
# SaleType_non_deed                       0.0457      0.017      2.746      0.006       0.013       0.078
# SaleCondition_not_normal               -0.0478      0.014     -3.323      0.001      -0.076      -0.020
# IsVinyl_yes                             0.0106      0.012      0.913      0.361      -0.012       0.033
# FullBaths_<=1FullBath                  -0.0518      0.013     -3.977      0.000      -0.077      -0.026
# FullBaths_>=3FullBaths                  0.0609      0.013      4.853      0.000       0.036       0.086
# HalfBaths_>=1HalfBaths                  0.0519      0.011      4.556      0.000       0.030       0.074
# Enclosed_combined_EnclosedPorch_Yes     0.0416      0.011      3.692      0.000       0.019       0.064
# ==============================================================================
# Omnibus:                      478.731   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7132.617
# Skew:                          -1.481   Prob(JB):                         0.00
# Kurtosis:                      14.739   Cond. No.                     2.44e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.94e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
ols.fit(X_train, y_train)
print("Train Set")
print(10*"~")
print("RSS: %.2f" % np.sum(((y_train) - (ols.predict(X_train))) ** 2))
print("RMSE: %.2f" % np.sqrt(np.sum(((y_train) - (ols.predict(X_train))) ** 2)/len(y_train)))
# Out:
# Train Set
# ~~~~~~~~~~
# RSS: 20.98
# RMSE: 0.13

# %% [markdown]
# # Benjamini–Hochberg procedure
# ### Controlling FDR

# %%
p_vals = model_fit.pvalues
print(len(p_vals))
BH = pd.DataFrame(p_vals.reset_index().sort_values(0))
BH = BH.rename(columns={'index': 'variable', 0: 'pval'})
BH['Rank'] = range(1,71)
BH['BH_pval'] = (BH.Rank/len(p_vals))*0.10 # 10% FDR
BH.head(5)
# Out:
# 70
#              variable          pval  Rank   BH_pval
# 4           GrLivArea  1.269075e-26     1  0.001429
# 35  TotalBsmtSF_small  9.792787e-17     2  0.002857
# 22   OverallCond_BadC  9.043961e-13     3  0.004286
# 20  OverallQual_HighQ  7.193267e-11     4  0.005714
# 34   TotalBsmtSF_mlow  7.133158e-09     5  0.007143

# %%
interesting = BH[BH.BH_pval > BH.pval] # 'interesting' variables from a univariate approach
print(len(interesting))
print(interesting)
plt.hist(p_vals)
# Out:
# 38
#                                variable          pval  Rank   BH_pval
# 4                             GrLivArea  1.269075e-26     1  0.001429
# 35                    TotalBsmtSF_small  9.792787e-17     2  0.002857
# 22                     OverallCond_BadC  9.043961e-13     3  0.004286
# 20                    OverallQual_HighQ  7.193267e-11     4  0.005714
# 34                     TotalBsmtSF_mlow  7.133158e-09     5  0.007143
# 37                 CentralAir_NoCentAir  1.679344e-08     6  0.008571
# 16                     Condition1_NormP  4.178518e-08     7  0.010000
# 14                   Neighborhood_NAmes  1.229023e-07     8  0.011429
# 21                     OverallQual_LowQ  2.291195e-07     9  0.012857
# 42                 KitchenQual_ExKtchnQ  2.871288e-07    10  0.014286
# 67               FullBaths_>=3FullBaths  1.391228e-06    11  0.015714
# 68               HalfBaths_>=1HalfBaths  5.797370e-06    12  0.017143
# 33                    TotalBsmtSF_mhigh  4.927564e-05    13  0.018571
# 66                FullBaths_<=1FullBath  7.446955e-05    14  0.020000
# 15                   Neighborhood_SAmes  1.060409e-04    15  0.021429
# 46                   Functional_TypFunc  1.678008e-04    16  0.022857
# 69  Enclosed_combined_EnclosedPorch_Yes  2.334802e-04    17  0.024286
# 23                    OverallCond_GoodC  2.339308e-04    18  0.025714
# 32             BsmtFinType1_undeveloped  2.915490e-04    19  0.027143
# 18                   BldgType_Townhouse  3.095392e-04    20  0.028571
# 64             SaleCondition_not_normal  9.210890e-04    21  0.030000
# 41                KitchenAbvGr_>=2Ktchn  1.147407e-03    22  0.031429
# 2                               LotArea  1.404193e-03    23  0.032857
# 48             FireplaceQu_OthFireplace  1.915182e-03    24  0.034286
# 1                           LotFrontage  2.025065e-03    25  0.035714
# 43                 KitchenQual_GdKtchnQ  3.742242e-03    26  0.037143
# 63                    SaleType_non_deed  6.132780e-03    27  0.038571
# 55                  GarageCars_AtLeast3  7.761922e-03    28  0.040000
# 54                         GarageCars_2  9.352444e-03    29  0.041429
# 0                                 const  9.676603e-03    30  0.042857
# 53                         GarageCars_1  1.051318e-02    31  0.044286
# 51             GarageFinish_NoGarageFin  1.147034e-02    32  0.045714
# 58                         PavedDrive_Y  1.617758e-02    33  0.047143
# 62                   MoSold_peak_months  3.135303e-02    34  0.048571
# 11                    LotConfig_CulDSac  3.699105e-02    35  0.050000
# 29                         BsmtQual_low  3.807360e-02    36  0.051429
# 26                        ExterQual_low  4.468089e-02    37  0.052857
# 28                     Foundation_pconc  5.199188e-02    38  0.054286
# (array([42.,  5.,  1.,  5.,  5.,  1.,  1.,  4.,  3.,  3.]),
#  array([1.26907506e-26, 9.97587672e-02, 1.99517534e-01, 2.99276301e-01,
#         3.99035069e-01, 4.98793836e-01, 5.98552603e-01, 6.98311370e-01,
#         7.98070137e-01, 8.97828904e-01, 9.97587672e-01]),
#  <a list of 10 Patch objects>)

# %%
# fitted values (need a constant term for intercept)
model_fitted_y = model_fit.fittedvalues

# model residuals
model_residuals = model_fit.resid

# normalized residuals
model_norm_residuals = model_fit.get_influence().resid_studentized_internal

# absolute squared normalized residuals
model_norm_residuals_abs_sqrt = np.sqrt(np.abs(model_norm_residuals))

# absolute residuals
model_abs_resid = np.abs(model_residuals)

# leverage, from statsmodels internals
model_leverage = model_fit.get_influence().hat_matrix_diag

# cook's distance, from statsmodels internals
model_cooks = model_fit.get_influence().cooks_distance[0]

# %% [markdown]
# # Residual Plots

# %%
plot_lm_1 = plt.figure(1)
plot_lm_1.set_figheight(8)
plot_lm_1.set_figwidth(12)

plot_lm_1.axes[0] = sns.residplot(model_fitted_y, np.log(group_train.SalePrice), 
                          lowess=True, 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_1.axes[0].set_title('Residuals vs Fitted')
plot_lm_1.axes[0].set_xlabel('Fitted values')
plot_lm_1.axes[0].set_ylabel('Residuals')

# annotations
abs_resid = model_abs_resid.sort_values(ascending=False)
abs_resid_top_3 = abs_resid[:10]

for i in abs_resid_top_3.index:
    plot_lm_1.axes[0].annotate(i, 
                               xy=(model_fitted_y[i], 
                                   model_residuals[i]));

# %%
plt.hist(model_fit.resid,bins=20)
# Out:
# (array([  1.,   1.,   0.,   0.,   0.,   2.,   3.,   4.,   4.,   6.,  29.,
#         124., 341., 378., 191.,  55.,  22.,   4.,   2.,   1.]),
#  array([-1.18951087, -1.09901892, -1.00852696, -0.91803501, -0.82754306,
#         -0.73705111, -0.64655915, -0.5560672 , -0.46557525, -0.37508329,
#         -0.28459134, -0.19409939, -0.10360744, -0.01311548,  0.07737647,
#          0.16786842,  0.25836037,  0.34885233,  0.43934428,  0.52983623,
#          0.62032818]),
#  <a list of 20 Patch objects>)

# %%
fanpoints = abs_resid_top_3
#print(fanpoints.index)
fanning = group_train.loc[[ 465,  907],:]
fanning
# Out:
#            LotFrontage  LotArea  YearBuilt  GrLivArea  YrSold  SalePrice  \
# random_id
# 465              130.0    40094          3       4676    2007     184750
# 907              313.0    63887          2       5642    2008     160000
#
#            MSZoning_RL  MSZoning_RMH  Alley_NoAccess  LotShape_Regular  \
# random_id
# 465                  1             0               1                 0
# 907                  1             0               1                 0
#
#                           ...                   OpenPorchSF_OpenPorch_Yes  \
# random_id                 ...
# 465                       ...                                           1
# 907                       ...                                           1
#
#            Fence_no_fence  MoSold_peak_months  SaleType_non_deed  \
# random_id
# 465                     1                   0                  1
# 907                     1                   0                  1
#
#            SaleCondition_not_normal  IsVinyl_yes  FullBaths_<=1FullBath  \
# random_id
# 465                               1            0                      0
# 907                               1            0                      0
#
#            FullBaths_>=3FullBaths  HalfBaths_>=1HalfBaths  \
# random_id
# 465                             1                       1
# 907                             1                       1
#
#            Enclosed_combined_EnclosedPorch_Yes
# random_id
# 465                                          0
# 907                                          0
#
# [2 rows x 70 columns]

# %%
plot_lm_4 = plt.figure(4)
plot_lm_4.set_figheight(8)
plot_lm_4.set_figwidth(12)

plt.scatter(model_leverage, model_norm_residuals, alpha=0.5)
sns.regplot(model_leverage, model_norm_residuals, 
            scatter=False, 
            ci=False, 
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_4.axes[0].set_xlim(0, 0.20)
plot_lm_4.axes[0].set_ylim(-3, 5)
plot_lm_4.axes[0].set_title('Residuals vs Leverage')
plot_lm_4.axes[0].set_xlabel('Leverage')
plot_lm_4.axes[0].set_ylabel('Standardized Residuals')

# annotations
leverage_top_3 = np.flip(np.argsort(model_cooks), 0)[:20]

for i in leverage_top_3:
    plot_lm_4.axes[0].annotate(i, 
                               xy=(model_leverage[i], 
                                   model_norm_residuals[i]))
    
# shenanigans for cook's distance contours
def graph(formula, x_range, label=None):
    x = x_range
    y = formula(x)
    plt.plot(x, y, label=label, lw=1, ls='--', color='red')

p = len(model_fit.params) # number of model parameters

graph(lambda x: np.sqrt((0.5 * p * (1 - x)) / x), 
      np.linspace(0.001, 0.200, 50), 
      'Cook\'s distance') # 0.5 line
graph(lambda x: np.sqrt((1 * p * (1 - x)) / x), 
      np.linspace(0.001, 0.200, 50)) # 1 line
plt.legend(loc='upper right');

# %%
QQ = ProbPlot(model_norm_residuals)
plot_lm_2 = QQ.qqplot(line='45', alpha=0.5, color='#4C72B0', lw=1)

plot_lm_2.set_figheight(8)
plot_lm_2.set_figwidth(12)

plot_lm_2.axes[0].set_title('Normal Q-Q')
plot_lm_2.axes[0].set_xlabel('Theoretical Quantiles')
plot_lm_2.axes[0].set_ylabel('Standardized Residuals');

# annotations
abs_norm_resid = np.flip(np.argsort(np.abs(model_norm_residuals)), 0)
abs_norm_resid_top_3 = abs_norm_resid[:10]

for r, i in enumerate(abs_norm_resid_top_3):
    plot_lm_2.axes[0].annotate(i, 
                               xy=(np.flip(QQ.theoretical_quantiles, 0)[r],
                                   model_norm_residuals[i]));

# %%
plt.hist(model_norm_residuals_abs_sqrt)
# Out:
# (array([145., 358., 414., 170.,  58.,  12.,   8.,   1.,   0.,   2.]),
#  array([0.02722469, 0.34668349, 0.66614228, 0.98560107, 1.30505986,
#         1.62451866, 1.94397745, 2.26343624, 2.58289504, 2.90235383,
#         3.22181262]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(model_norm_residuals)
# Out:
# (array([  1.,   1.,   0.,   5.,   8.,  45., 604., 456.,  45.,   3.]),
#  array([-10.38007657,  -8.87488216,  -7.36968774,  -5.86449333,
#          -4.35929891,  -2.8541045 ,  -1.34891009,   0.15628433,
#           1.66147874,   3.16667316,   4.67186757]),
#  <a list of 10 Patch objects>)

# %%
plot_lm_3 = plt.figure(3)
plot_lm_3.set_figheight(8)
plot_lm_3.set_figwidth(12)

plt.scatter(model_fitted_y, model_norm_residuals_abs_sqrt, alpha=0.5)
sns.regplot(model_fitted_y, model_norm_residuals_abs_sqrt, 
            scatter=False, 
            ci=False, 
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_3.axes[0].set_title('Scale-Location')
plot_lm_3.axes[0].set_xlabel('Fitted values')
plot_lm_3.axes[0].set_ylabel('$\sqrt{|Standardized Residuals|}$');

# annotations
abs_sq_norm_resid = np.flip(np.argsort(model_norm_residuals_abs_sqrt), 0)
abs_sq_norm_resid_top_3 = abs_sq_norm_resid[:3]

for i in abs_norm_resid_top_3:
    plot_lm_3.axes[0].annotate(i, 
                               xy=(model_fitted_y[i], 
                                   model_norm_residuals_abs_sqrt[i]));
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-a6badd11ca9a> in <module>()
#      20 for i in abs_norm_resid_top_3:
#      21     plot_lm_3.axes[0].annotate(i,
# ---> 22                                xy=(model_fitted_y[i],
#      23                                    model_norm_residuals_abs_sqrt[i]));
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2558         try:
#    2559             return self._engine.get_value(s, k,
# -> 2560                                           tz=getattr(series.dtype, 'tz', None))
#    2561         except KeyError as e1:
#    2562             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 172
