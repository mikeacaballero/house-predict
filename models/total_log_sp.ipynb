# %%
# define indicies
import numpy as np

np.random.seed(9)

house_ids = range(1,1461)
random_id = np.random.choice(house_ids, 1460, replace = False)
len(random_id)
# Out:
# 1460

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/train_model.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  Id  LotFrontage  LotArea  YearBuilt  GrLivArea  YrSold  \
# 0           0   1         65.0     8450          7       1710    2008
# 1           1   2         80.0     9600         34       1262    2007
# 2           2   3         68.0    11250          9       1786    2008
# 3           3   4         60.0     9550         95       1717    2006
# 4           4   5         84.0    14260         10       2198    2008
#
#    SalePrice  MSZoning_RL  MSZoning_RMH                 ...                   \
# 0     208500            1             0                 ...
# 1     181500            1             0                 ...
# 2     223500            1             0                 ...
# 3     140000            1             0                 ...
# 4     250000            1             0                 ...
#
#    OpenPorchSF_OpenPorch_Yes  Fence_no_fence  MoSold_peak_months  \
# 0                          1               1                   0
# 1                          0               1                   1
# 2                          1               1                   0
# 3                          1               1                   0
# 4                          1               1                   0
#
#    SaleType_non_deed  SaleCondition_not_normal  IsVinyl_yes  \
# 0                  0                         0            1
# 1                  0                         0            0
# 2                  0                         0            1
# 3                  0                         1            0
# 4                  0                         0            1
#
#    FullBaths_<=1FullBath  FullBaths_>=3FullBaths  HalfBaths_>=1HalfBaths  \
# 0                      0                       1                       1
# 1                      0                       0                       1
# 2                      0                       1                       1
# 3                      0                       0                       0
# 4                      0                       1                       1
#
#    Enclosed_combined_EnclosedPorch_Yes
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    1
# 4                                    0
#
# [5 rows x 72 columns]

# %%
df.drop(columns = ['Unnamed: 0', 'Id'], inplace = True)

# %%
df['random_id'] = random_id

# %%
df.set_index('random_id', inplace = True)

# %%
df.sort_index(inplace=True)
df
# Out:
#            LotFrontage  LotArea  YearBuilt  GrLivArea  YrSold  SalePrice  \
# random_id
# 1            87.000000     9246         37       1656    2008     135000
# 2            60.000000     7200         60       1904    2009     138000
# 3            74.000000     8532         56       1297    2009     153000
# 4            47.000000    53504          7       3279    2010     538000
# 5            82.000000     9430         11       2365    2009     337000
# 6            50.000000    10300         89       1710    2010     140000
# 7            74.000000     8536          4       1125    2007     155000
# 8            80.000000    10400         34       1370    2009     152000
# 9            70.049958    11425         56       1008    2006     137000
# 10           70.049958     7446         69        788    2006     100000
# 11           79.000000     9416          3       1726    2007     311872
# 12           70.049958    12155         85       1482    2008     140000
# 13           60.000000     7500         11       1804    2010     189000
# 14           43.000000     3013          5       1506    2006     213490
# 15           70.049958     8963         34       2715    2008     299800
# 16           80.000000     8800         46       1251    2006     160000
# 17           70.049958    12692         18       3228    2007     430000
# 18           70.049958    10530         39        981    2007     143250
# 19           64.000000     6979         30       1056    2010     144000
# 20           95.000000    15865         40       2217    2007     268000
# 21           70.000000     7931         51       1148    2009     132500
# 22           48.000000    17043         31       1586    2009     181000
# 23           70.049958    10316         10       1865    2008     235000
# 24           60.000000     7024          5       1090    2007     157000
# 25           70.049958    14585         50       1429    2007     181900
# 26          104.000000    21535         16       4316    2007     755000
# 27           96.000000    11308          2       2184    2009     335000
# 28           68.000000     8814          4       1604    2009     220000
# 29           72.000000    10152         54       1048    2007     135000
# 30           79.000000    10289         45       1073    2007     156000
# ...                ...      ...        ...        ...     ...        ...
# 1431         60.000000    11100         64        930    2010      84900
# 1432        116.000000    13474         20       2243    2007     225000
# 1433         30.000000     3000          1       1224    2009     173733
# 1434         70.049958     8755         11       2060    2009     214000
# 1435         50.000000     8012         17       1617    2008     193000
# 1436         70.049958    18800         34       1574    2006     190000
# 1437         85.000000    11475         52       1776    2009     110000
# 1438         70.049958    12122         49        999    2008     178400
# 1439         72.000000    10007         51       1053    2008     145500
# 1440         70.000000     8521         43        912    2010     125000
# 1441        120.000000     9560         38        864    2006     128500
# 1442         70.049958    26142         48       1188    2010     157900
# 1443         60.000000     6780         75        754    2006      84500
# 1444         70.049958    12772         50        958    2007     151500
# 1445         66.000000     7742         44        955    2007     127000
# 1446         70.049958    16381         41       1844    2006     223000
# 1447         65.000000    12257         15       2531    2007     290000
# 1448         60.000000     9600         60       1067    2010     128000
# 1449         91.000000    14303         16       1987    2008     301500
# 1450         51.000000     3635          3       1569    2009     175900
# 1451         70.049958     5814         26       1360    2009     187500
# 1452         61.000000     7259         65       2320    2007     259500
# 1453         78.000000    12090         29       1422    2008     175500
# 1454         60.000000     8544         60       1040    2006      93500
# 1455         70.049958     9636         18       1593    2009     178000
# 1456         62.000000    70761         35       1533    2006     280000
# 1457        120.000000    15611          4       1919    2006     233230
# 1458         98.000000    12256         16       2622    2010     325000
# 1459         95.000000    11345         62       1920    2007     137000
# 1460         60.000000     6402         90       1192    2009      78000
#
#            MSZoning_RL  MSZoning_RMH  Alley_NoAccess  LotShape_Regular  \
# random_id
# 1                    1             0               1                 0
# 2                    1             0               1                 1
# 3                    1             0               1                 1
# 4                    1             0               1                 0
# 5                    1             0               1                 1
# 6                    0             1               1                 0
# 7                    1             0               1                 1
# 8                    1             0               1                 1
# 9                    1             0               1                 0
# 10                   1             0               1                 1
# 11                   1             0               1                 1
# 12                   0             1               1                 0
# 13                   1             0               1                 1
# 14                   1             0               1                 1
# 15                   1             0               1                 0
# 16                   1             0               1                 1
# 17                   1             0               1                 0
# 18                   1             0               1                 0
# 19                   1             0               1                 1
# 20                   1             0               1                 0
# 21                   1             0               1                 1
# 22                   1             0               1                 0
# 23                   1             0               1                 0
# 24                   1             0               1                 1
# 25                   1             0               1                 0
# 26                   1             0               1                 0
# 27                   1             0               1                 0
# 28                   1             0               1                 1
# 29                   1             0               1                 1
# 30                   1             0               1                 1
# ...                ...           ...             ...               ...
# 1431                 1             0               1                 1
# 1432                 1             0               1                 1
# 1433                 0             0               0                 1
# 1434                 1             0               1                 0
# 1435                 1             0               1                 1
# 1436                 1             0               1                 0
# 1437                 1             0               1                 1
# 1438                 1             0               1                 0
# 1439                 1             0               1                 0
# 1440                 1             0               1                 1
# 1441                 1             0               1                 0
# 3                       1                   0                  0
# 4                       1                   1                  0
# 5                       1                   1                  0
#
#            SaleCondition_not_normal  IsVinyl_yes  FullBaths_<=1FullBath  \
# random_id
# 1                                 0            0                      0
# 2                                 0            1                      0
# 3                                 0            0                      1
# 4                                 0            0                      0
# 5                                 0            1                      0
#
#            FullBaths_>=3FullBaths  HalfBaths_>=1HalfBaths  \
# random_id
# 1                               0                       0
# 2                               0                       1
# 3                               0                       1
# 4                               1                       1
# 5                               1                       1
#
#            Enclosed_combined_EnclosedPorch_Yes
# random_id
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            1
# 5                                            1
#
# [5 rows x 70 columns]

# %%
test_1 = df.iloc[0:292,:]
test_2 = df.iloc[292:584,:]
test_3 = df.iloc[584:876,:]
test_4 = df.iloc[876:1168,:]
test_5 = df.iloc[1168:1460,:]

# %%
print(len(test_1))
print(len(test_2))
print(len(test_3))
print(len(test_4))
print(len(test_5))
# Out:
# 292
# 292
# 292
# 292
# 292

# %%
group_test = test_1.copy()
group_train = pd.concat([test_2, test_3, test_4, test_5])
group_train.shape
group_train.head(5)
# Out:
#            LotFrontage  LotArea  YearBuilt  GrLivArea  YrSold  SalePrice  \
# random_id
# 293          70.049958    13837         22       2183    2006     229000
# 294          51.000000     8029          5       1456    2008     176000
# 295          86.000000    13286          3       1698    2009     320000
# 296          60.000000     9600         86       1096    2008      79000
# 297          90.000000    10800         36       2614    2008     240000
#
#            MSZoning_RL  MSZoning_RMH  Alley_NoAccess  LotShape_Regular  \
# random_id
# 293                  1             0               1                 0
# 294                  1             0               1                 0
# 295                  1             0               1                 0
# 296                  1             0               1                 1
# 297                  1             0               1                 1
#
#                           ...                   OpenPorchSF_OpenPorch_Yes  \
# random_id                 ...
# 293                       ...                                           0
# 294                       ...                                           1
# 295                       ...                                           1
# 296                       ...                                           1
# 297                       ...                                           1
#
#            Fence_no_fence  MoSold_peak_months  SaleType_non_deed  \
# random_id
# 293                     1                   0                  0
# 294                     1                   1                  0
# 295                     1                   0                  0
# 296                     1                   0                  0
# 297                     1                   1                  0
#
#            SaleCondition_not_normal  IsVinyl_yes  FullBaths_<=1FullBath  \
# random_id
# 293                               0            0                      0
# 294                               0            1                      0
# 295                               0            0                      0
# 296                               0            0                      1
# 297                               0            0                      0
#
#            FullBaths_>=3FullBaths  HalfBaths_>=1HalfBaths  \
# random_id
# 293                             0                       1
# 294                             0                       1
# 295                             1                       0
# 296                             0                       0
# 297                             0                       1
#
#            Enclosed_combined_EnclosedPorch_Yes
# random_id
# 293                                          0
# 294                                          0
# 295                                          0
# 296                                          1
# 297                                          0
#
# [5 rows x 70 columns]

# %% [markdown]
# # Model

# %%
from sklearn import linear_model
ols = linear_model.LinearRegression()

# %%
X_train = df.drop(['SalePrice'], axis = 1)
y_train = np.log(df.SalePrice)

#X_test = group_test.drop('SalePrice', axis = 1)
#y_test = np.log(group_test.SalePrice)

# %% [markdown]
# https://medium.com/@emredjan/emulating-r-regression-plots-in-python-43741952c034

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm

from statsmodels.graphics.gofplots import ProbPlot

plt.style.use('seaborn') # pretty matplotlib plots

plt.rc('font', size=14)
plt.rc('figure', titlesize=18)
plt.rc('axes', labelsize=15)
plt.rc('axes', titlesize=18)
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
X_train = sm.add_constant(X_train) 
model2 = sm.OLS(y_train, X_train)
model_fit2 = model2.fit()
#print(model_fit2.summary())

# %%
X_train = sm.add_constant(X_train) 
model = smf.OLS(y_train, X_train)
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     158.5
# Date:                Wed, 30 May 2018   Prob (F-statistic):               0.00
# Time:                        19:36:27   Log-Likelihood:                 852.08
# No. Observations:                1460   AIC:                            -1566.
# Df Residuals:                    1391   BIC:                            -1201.
# Df Model:                          68
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  14.5193      4.553      3.189      0.001       5.588      23.451
# LotFrontage                            -0.0004      0.000     -1.646      0.100      -0.001    7.03e-05
# LotArea                              1.548e-06   4.34e-07      3.563      0.000    6.96e-07     2.4e-06
# YearBuilt                              -0.0004      0.000     -1.358      0.175      -0.001       0.000
# GrLivArea                               0.0002   1.51e-05     14.088      0.000       0.000       0.000
# YrSold                                 -0.0032      0.003     -1.127      0.260      -0.009       0.002
# MSZoning_RL                             0.0159      0.020      0.789      0.430      -0.024       0.056
# MSZoning_RMH                           -0.0166      0.022     -0.748      0.455      -0.060       0.027
# Alley_NoAccess                         -0.0245      0.018     -1.397      0.163      -0.059       0.010
# LotShape_Regular                       -0.0012      0.009     -0.137      0.891      -0.019       0.016
# LandContour_Unflat                     -0.0198      0.015     -1.297      0.195      -0.050       0.010
# LotConfig_CulDSac                       0.0425      0.018      2.390      0.017       0.008       0.077
# LotConfig_Inside                       -0.0107      0.009     -1.141      0.254      -0.029       0.008
# LandSlope_NGtl                          0.0353      0.021      1.716      0.086      -0.005       0.076
# Neighborhood_NAmes                      0.0868      0.014      6.001      0.000       0.058       0.115
# Neighborhood_SAmes                      0.0539      0.012      4.582      0.000       0.031       0.077
# Condition1_NormP                        0.0619      0.012      5.207      0.000       0.039       0.085
# BldgType_OneFamily                     -0.0295      0.029     -1.020      0.308      -0.086       0.027
# BldgType_Townhouse                     -0.1141      0.032     -3.528      0.000      -0.178      -0.051
# HouseStyle_OneStoryUp                  -0.0039      0.012     -0.332      0.740      -0.027       0.019
# OverallQual_HighQ                       0.1103      0.015      7.427      0.000       0.081       0.139
# OverallQual_LowQ                       -0.0959      0.015     -6.532      0.000      -0.125      -0.067
# OverallCond_BadC                       -0.1362      0.018     -7.747      0.000      -0.171      -0.102
# OverallCond_GoodC                       0.0677      0.017      3.972      0.000       0.034       0.101
# RoofStyle_not_gable                     0.0231      0.010      2.403      0.016       0.004       0.042
# MasVnrType_no_masvnr                    0.0005      0.009      0.053      0.958      -0.017       0.018
# ExterQual_low                          -0.0303      0.013     -2.248      0.025      -0.057      -0.004
# MoSold_peak_months                      0.0165      0.007      2.215      0.027       0.002       0.031
# SaleType_non_deed                       0.0504      0.015      3.413      0.001       0.021       0.079
# SaleCondition_not_normal               -0.0543      0.013     -4.252      0.000      -0.079      -0.029
# IsVinyl_yes                            -0.0027      0.010     -0.261      0.794      -0.023       0.018
# FullBaths_<=1FullBath                  -0.0440      0.012     -3.805      0.000      -0.067      -0.021
# FullBaths_>=3FullBaths                  0.0586      0.011      5.224      0.000       0.037       0.081
# HalfBaths_>=1HalfBaths                  0.0429      0.010      4.232      0.000       0.023       0.063
# Enclosed_combined_EnclosedPorch_Yes     0.0367      0.010      3.714      0.000       0.017       0.056
# ==============================================================================
# Omnibus:                      653.684   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12368.910
# Skew:                          -1.610   Prob(JB):                         0.00
# Kurtosis:                      16.891   Cond. No.                     3.37e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.75e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
ols.fit(X_train, y_train)
print("Full Set")
print(10*"~")
print("RSS: %.2f" % np.sum(((y_train) - (ols.predict(X_train))) ** 2))
print("RMSE: %.2f" % np.sqrt(np.sum(((y_train) - (ols.predict(X_train))) ** 2)/len(y_train)))
# Out:
# Full Set
# ~~~~~~~~~~
# RSS: 26.60
# RMSE: 0.13

# %% [markdown]
# # Benjamini–Hochberg procedure
# ### Controlling FDR

# %%
p_vals = model_fit.pvalues
print(len(p_vals))
BH = pd.DataFrame(p_vals.reset_index().sort_values(0))
BH = BH.rename(columns={'index': 'variable', 0: 'pval'})
BH['Rank'] = range(1,71)
BH['BH_pval'] = (BH.Rank/len(p_vals))*0.10 # 10% FDR
BH.head(5)
# Out:
# 70
#              variable          pval  Rank   BH_pval
# 4           GrLivArea  3.092223e-42     1  0.001429
# 35  TotalBsmtSF_small  4.047689e-18     2  0.002857
# 22   OverallCond_BadC  1.801910e-14     3  0.004286
# 20  OverallQual_HighQ  1.925325e-13     4  0.005714
# 21   OverallQual_LowQ  9.076847e-11     5  0.007143

# %%
interesting = BH[BH.BH_pval > BH.pval] # 'interesting' variables from a univariate approach
print(len(interesting))
print(interesting)
plt.hist(p_vals)
# Out:
# 42
#                                variable          pval  Rank   BH_pval
# 4                             GrLivArea  3.092223e-42     1  0.001429
# 35                    TotalBsmtSF_small  4.047689e-18     2  0.002857
# 22                     OverallCond_BadC  1.801910e-14     3  0.004286
# 20                    OverallQual_HighQ  1.925325e-13     4  0.005714
# 21                     OverallQual_LowQ  9.076847e-11     5  0.007143
# 42                 KitchenQual_ExKtchnQ  2.162688e-10     6  0.008571
# 14                   Neighborhood_NAmes  2.495091e-09     7  0.010000
# 34                     TotalBsmtSF_mlow  5.456202e-09     8  0.011429
# 37                 CentralAir_NoCentAir  8.957153e-09     9  0.012857
# 67               FullBaths_>=3FullBaths  2.021096e-07    10  0.014286
# 16                     Condition1_NormP  2.207181e-07    11  0.015714
# 33                    TotalBsmtSF_mhigh  4.512232e-06    12  0.017143
# 15                   Neighborhood_SAmes  5.025103e-06    13  0.018571
# 64             SaleCondition_not_normal  2.261302e-05    14  0.020000
# 68               HalfBaths_>=1HalfBaths  2.472319e-05    15  0.021429
# 32             BsmtFinType1_undeveloped  4.845320e-05    16  0.022857
# 46                   Functional_TypFunc  6.896203e-05    17  0.024286
# 23                    OverallCond_GoodC  7.484289e-05    18  0.025714
# 66                FullBaths_<=1FullBath  1.479110e-04    19  0.027143
# 69  Enclosed_combined_EnclosedPorch_Yes  2.123027e-04    20  0.028571
# 2                               LotArea  3.790122e-04    21  0.030000
# 18                   BldgType_Townhouse  4.322738e-04    22  0.031429
# 63                    SaleType_non_deed  6.620232e-04    23  0.032857
# 55                  GarageCars_AtLeast3  1.099626e-03    24  0.034286
# 54                         GarageCars_2  1.415082e-03    25  0.035714
# 0                                 const  1.459512e-03    26  0.037143
# 53                         GarageCars_1  1.605324e-03    27  0.038571
# 51             GarageFinish_NoGarageFin  1.814262e-03    28  0.040000
# 48             FireplaceQu_OthFireplace  2.608324e-03    29  0.041429
# 36                        HeatingQC_low  5.658106e-03    30  0.042857
# 43                 KitchenQual_GdKtchnQ  5.930854e-03    31  0.044286
# 41                KitchenAbvGr_>=2Ktchn  8.841038e-03    32  0.045714
# 24                  RoofStyle_not_gable  1.640702e-02    33  0.047143
# 11                    LotConfig_CulDSac  1.699315e-02    34  0.048571
# 58                         PavedDrive_Y  2.080597e-02    35  0.050000
# 57       GarageCond_GarageCond_not_good  2.100665e-02    36  0.051429
# 31             BsmtExposure_no_exposure  2.129059e-02    37  0.052857
# 26                        ExterQual_low  2.475983e-02    38  0.054286
# 47               Fireplaces_NoFireplace  2.520309e-02    39  0.055714
# 62                   MoSold_peak_months  2.692133e-02    40  0.057143
# 29                         BsmtQual_low  4.002294e-02    41  0.058571
# 44               TotRmsAbvGrd_<=4TotRms  5.682667e-02    42  0.060000
# (array([43.,  5.,  4.,  3.,  4.,  1.,  0.,  5.,  1.,  4.]),
#  array([3.09222338e-42, 9.97752771e-02, 1.99550554e-01, 2.99325831e-01,
#         3.99101109e-01, 4.98876386e-01, 5.98651663e-01, 6.98426940e-01,
#         7.98202217e-01, 8.97977494e-01, 9.97752771e-01]),
#  <a list of 10 Patch objects>)

# %%
# fitted values (need a constant term for intercept)
model_fitted_y = model_fit.fittedvalues

# model residuals
model_residuals = model_fit.resid

# normalized residuals
model_norm_residuals = model_fit.get_influence().resid_studentized_internal

# absolute squared normalized residuals
model_norm_residuals_abs_sqrt = np.sqrt(np.abs(model_norm_residuals))

# absolute residuals
model_abs_resid = np.abs(model_residuals)

# leverage, from statsmodels internals
model_leverage = model_fit.get_influence().hat_matrix_diag

# cook's distance, from statsmodels internals
model_cooks = model_fit.get_influence().cooks_distance[0]

# %% [markdown]
# # Residual Plots

# %%
plot_lm_1 = plt.figure(1)
plot_lm_1.set_figheight(8)
plot_lm_1.set_figwidth(12)

plot_lm_1.axes[0] = sns.residplot(model_fitted_y, np.log(df.SalePrice), 
                          lowess=True, 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_1.axes[0].set_title('Residuals vs Fitted')
plot_lm_1.axes[0].set_xlabel('Fitted values')
plot_lm_1.axes[0].set_ylabel('Residuals')

# annotations
abs_resid = model_abs_resid.sort_values(ascending=False)
abs_resid_top_3 = abs_resid[:3]

for i in abs_resid_top_3.index:
    plot_lm_1.axes[0].annotate(i, 
                               xy=(model_fitted_y[i], 
                                   model_residuals[i]));

# %%
plt.hist(model_norm_residuals,bins=20)
# Out:
# (array([  1.,   0.,   1.,   0.,   0.,   0.,   0.,   3.,   4.,   4.,   7.,
#          34., 154., 522., 509., 157.,  56.,   6.,   1.,   1.]),
#  array([-1.13359748e+01, -1.05256427e+01, -9.71531068e+00, -8.90497862e+00,
#         -8.09464656e+00, -7.28431450e+00, -6.47398244e+00, -5.66365038e+00,
#         -4.85331832e+00, -4.04298626e+00, -3.23265420e+00, -2.42232214e+00,
#         -1.61199008e+00, -8.01658015e-01,  8.67404547e-03,  8.19006106e-01,
#          1.62933817e+00,  2.43967023e+00,  3.25000229e+00,  4.06033435e+00,
#          4.87066641e+00]),
#  <a list of 20 Patch objects>)

# %%
fanpoints = abs_resid_top_3
#print(fanpoints.index)
fanning = group_train.loc[[ 465,  907],:]
fanning
# Out:
#            LotFrontage  LotArea  YearBuilt  GrLivArea  YrSold  SalePrice  \
# random_id
# 465              130.0    40094          3       4676    2007     184750
# 907              313.0    63887          2       5642    2008     160000
#
#            MSZoning_RL  MSZoning_RMH  Alley_NoAccess  LotShape_Regular  \
# random_id
# 465                  1             0               1                 0
# 907                  1             0               1                 0
#
#                           ...                   OpenPorchSF_OpenPorch_Yes  \
# random_id                 ...
# 465                       ...                                           1
# 907                       ...                                           1
#
#            Fence_no_fence  MoSold_peak_months  SaleType_non_deed  \
# random_id
# 465                     1                   0                  1
# 907                     1                   0                  1
#
#            SaleCondition_not_normal  IsVinyl_yes  FullBaths_<=1FullBath  \
# random_id
# 465                               1            0                      0
# 907                               1            0                      0
#
#            FullBaths_>=3FullBaths  HalfBaths_>=1HalfBaths  \
# random_id
# 465                             1                       1
# 907                             1                       1
#
#            Enclosed_combined_EnclosedPorch_Yes
# random_id
# 465                                          0
# 907                                          0
#
# [2 rows x 70 columns]

# %%
plot_lm_4 = plt.figure(4)
plot_lm_4.set_figheight(8)
plot_lm_4.set_figwidth(12)

plt.scatter(model_leverage, model_norm_residuals, alpha=0.5)
sns.regplot(model_leverage, model_norm_residuals, 
            scatter=False, 
            ci=False, 
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_4.axes[0].set_xlim(0, 0.20)
plot_lm_4.axes[0].set_ylim(-3, 5)
plot_lm_4.axes[0].set_title('Residuals vs Leverage')
plot_lm_4.axes[0].set_xlabel('Leverage')
plot_lm_4.axes[0].set_ylabel('Standardized Residuals')

# annotations
leverage_top_3 = np.flip(np.argsort(model_cooks), 0)[:20]

for i in leverage_top_3:
    plot_lm_4.axes[0].annotate(i, 
                               xy=(model_leverage[i], 
                                   model_norm_residuals[i]))
    
# shenanigans for cook's distance contours
def graph(formula, x_range, label=None):
    x = x_range
    y = formula(x)
    plt.plot(x, y, label=label, lw=1, ls='--', color='red')

p = len(model_fit.params) # number of model parameters

graph(lambda x: np.sqrt((0.5 * p * (1 - x)) / x), 
      np.linspace(0.001, 0.200, 50), 
      'Cook\'s distance') # 0.5 line
graph(lambda x: np.sqrt((1 * p * (1 - x)) / x), 
      np.linspace(0.001, 0.200, 50)) # 1 line
plt.legend(loc='upper right');

# %%
QQ = ProbPlot(model_norm_residuals)
plot_lm_2 = QQ.qqplot(line='45', alpha=0.5, color='#4C72B0', lw=1)

plot_lm_2.set_figheight(8)
plot_lm_2.set_figwidth(12)

plot_lm_2.axes[0].set_title('Normal Q-Q')
plot_lm_2.axes[0].set_xlabel('Theoretical Quantiles')
plot_lm_2.axes[0].set_ylabel('Standardized Residuals');

# annotations
abs_norm_resid = np.flip(np.argsort(np.abs(model_norm_residuals)), 0)
abs_norm_resid_top_3 = abs_norm_resid[:3]

for r, i in enumerate(abs_norm_resid_top_3):
    plot_lm_2.axes[0].annotate(i, 
                               xy=(np.flip(QQ.theoretical_quantiles, 0)[r],
                                   model_norm_residuals[i]));

# %%
plt.hist(model_norm_residuals_abs_sqrt)
# Out:
# (array([180., 474., 508., 214.,  64.,  10.,   8.,   0.,   1.,   1.]),
#  array([0.00410982, 0.34038823, 0.67666665, 1.01294506, 1.34922347,
#         1.68550188, 2.02178029, 2.3580587 , 2.69433712, 3.03061553,
#         3.36689394]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(model_norm_residuals)
# Out:
# (array([  1.,   1.,   0.,   3.,   8.,  41., 676., 666.,  62.,   2.]),
#  array([-1.13359748e+01, -9.71531068e+00, -8.09464656e+00, -6.47398244e+00,
#         -4.85331832e+00, -3.23265420e+00, -1.61199008e+00,  8.67404547e-03,
#          1.62933817e+00,  3.25000229e+00,  4.87066641e+00]),
#  <a list of 10 Patch objects>)

# %%
plot_lm_3 = plt.figure(3)
plot_lm_3.set_figheight(8)
plot_lm_3.set_figwidth(12)

plt.scatter(model_fitted_y, model_norm_residuals_abs_sqrt, alpha=0.5)
sns.regplot(model_fitted_y, model_norm_residuals_abs_sqrt, 
            scatter=False, 
            ci=False, 
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_3.axes[0].set_title('Scale-Location')
plot_lm_3.axes[0].set_xlabel('Fitted values')
plot_lm_3.axes[0].set_ylabel('$\sqrt{|Standardized Residuals|}$');

# annotations
abs_sq_norm_resid = np.flip(np.argsort(model_norm_residuals_abs_sqrt), 0)
abs_sq_norm_resid_top_3 = abs_sq_norm_resid[:3]

for i in abs_norm_resid_top_3:
    plot_lm_3.axes[0].annotate(i, 
                               xy=(model_fitted_y[i], 
                                   model_norm_residuals_abs_sqrt[i]));
